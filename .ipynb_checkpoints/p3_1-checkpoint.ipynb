# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from textwrap import wrap
from adjustText import adjust_text
import math

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_xlabel('\n'.join(wrap("Years since 2024", 40)))
ax.set_ylabel('\n'.join(wrap("Percent %", 40)))

# Logistic Model 1
line_m1 = np.linspace(0, 50, 100)
polyspace_m1 = (197700/(217101*(1.07611**line_m1)) * ((1.08179/1.04244)**line_m1)) * ((0.0244103*line_m1) + 1.43219)
plt.plot(line_m1, polyspace_m1, label = "% Homelessness", color="red")

ax.legend()
plt.title("Homelessness Percentage Reduction Model")
# Out:
# Text(0.5, 1.0, 'Homelessness Percentage Model')
